# %% [markdown]
# # Algoshift\n\nPhase 2 notebook walkthrough.

# %%
import pandas as pd\nfrom algoshift import AlgoshiftCalculator\n

# %%
df = pd.read_csv("algoshift_dataset.csv")\ndf.head()\n

# %%
calc = AlgoshiftCalculator()\nresult = calc.calculate_algoshift(df)\nresult.head()\n

# %%
result["algoshift_index"].describe()\n

# %%
result.groupby("algoshift_band").size()\n

# %%
result["algoshift_index"].hist(bins=20)\n

# %% [markdown]
# Interpretation: `Algoshift` index is now ready for stress testing.
